# %%
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/kaggle-home-prices/
# Out:
# /content/drive/MyDrive/kaggle-home-prices

# %%
# !git config --global user.name "Brian Yoon"
# !git config --global user.email "byoon2002@gmail.com"
# !git remote set-url origin https://briancy02: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@github.com/briancy02/kaggle-home-prices.git
# !git commit -am "notebook changes"
# Out:
# [master a0464e3e] notebook changes
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite main_notebook.ipynb (85%)

# %%
# !git add .
# !git commit -am "improved rmse reducing fts and changing model"
# Out:
# [master 4ee8e3aa] improved rmse reducing fts and changing model
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite main_notebook.ipynb (84%)

# %%
# !git commit -am "added data viz"
# !git push
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 3 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
# 	gitFile.ipynb
#
# nothing added to commit but untracked files present
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 928.14 KiB | 9.87 MiB/s, done.
# Total 9 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 1 local object.
# To https://github.com/briancy02/kaggle-home-prices.git
#    b20f5b5f..d1387887  master -> master
